# %% [markdown]
# importing the required libraries

# %%
import requests
import lxml.html as lh
import bs4 as bs
import urllib.request
import numpy as np 
import pandas as pd

# %% [markdown]
# taking the data out by providing the URL

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
res = requests.get(url)
soup = bs.BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[0]
df = pd.read_html(str(table))
data = pd.read_json(df[0].to_json(orient='records'))

# %% [markdown]
# printing the data as a whole

# %%
data
# Out:
#               Borough                                       Neighborhood  \
# 0        Not assigned                                       Not assigned
# 1        Not assigned                                       Not assigned
# 2          North York                                          Parkwoods
# 3          North York                                   Victoria Village
# 4    Downtown Toronto                          Regent Park, Harbourfront
# 5          North York                   Lawrence Manor, Lawrence Heights
# 6    Downtown Toronto        Queen's Park, Ontario Provincial Government
# 7        Not assigned                                       Not assigned
# 8           Etobicoke            Islington Avenue, Humber Valley Village
# 9         Scarborough                                     Malvern, Rouge
# 10       Not assigned                                       Not assigned
# 11         North York                                          Don Mills
# 12          East York                    Parkview Hill, Woodbine Gardens
# 13   Downtown Toronto                           Garden District, Ryerson
# 14         North York                                          Glencairn
# 15       Not assigned                                       Not assigned
# 16       Not assigned                                       Not assigned
# 17          Etobicoke  West Deane Park, Princess Gardens, Martin Grov...
# 18        Scarborough             Rouge Hill, Port Union, Highland Creek
# 19       Not assigned                                       Not assigned
# 20         North York                                          Don Mills
# 21          East York                                   Woodbine Heights
# 22   Downtown Toronto                                     St. James Town
# 23               York                                 Humewood-Cedarvale
# 24       Not assigned                                       Not assigned
# 25       Not assigned                                       Not assigned
# 26          Etobicoke  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 27        Scarborough                  Guildwood, Morningside, West Hill
# 28       Not assigned                                       Not assigned
# 29       Not assigned                                       Not assigned
# ..                ...                                                ...
# 150      Not assigned                                       Not assigned
# 151         Etobicoke                             Alderwood, Long Branch
# 152         Etobicoke                Northwest, West Humber - Clairville
# 153       Scarborough                                        Upper Rouge
# 154      Not assigned                                       Not assigned
# 155      Not assigned                                       Not assigned
# 156  Downtown Toronto                        St. James Town, Cabbagetown
# 157  Downtown Toronto             First Canadian Place, Underground city
# 158      Not assigned                                       Not assigned
# 159      Not assigned                                       Not assigned
# 160         Etobicoke      The Kingsway, Montgomery Road, Old Mill North
# 161      Not assigned                                       Not assigned
# 162      Not assigned                                       Not assigned
# 163      Not assigned                                       Not assigned
# 164      Not assigned                                       Not assigned
# 165  Downtown Toronto                               Church and Wellesley
# 166      Not assigned                                       Not assigned
# 167      Not assigned                                       Not assigned
# 168      East Toronto  Business reply mail Processing Centre, South C...
# 169         Etobicoke  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 170      Not assigned                                       Not assigned
# 171      Not assigned                                       Not assigned
# 172      Not assigned                                       Not assigned
# 173      Not assigned                                       Not assigned
# 174      Not assigned                                       Not assigned
# 175      Not assigned                                       Not assigned
# 176      Not assigned                                       Not assigned
# 177      Not assigned                                       Not assigned
# 178         Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
# 179      Not assigned                                       Not assigned
#
#     Postal Code
# 0           M1A
# 1           M2A
# 2           M3A
# 3           M4A
# 4           M5A
# 5           M6A
# 6           M7A
# 7           M8A
# 8           M9A
# 9           M1B
# 10          M2B
# 11          M3B
# 12          M4B
# 13          M5B
# 14          M6B
# 15          M7B
# 16          M8B
# 17          M9B
# 18          M1C
# 19          M2C
# 20          M3C
# 21          M4C
# 22          M5C
# 23          M6C
# 24          M7C
# 25          M8C
# 26          M9C
# 27          M1E
# 28          M2E
# 29          M3E
# ..          ...
# 150         M7W
# 151         M8W
# 152         M9W
# 153         M1X
# 154         M2X
# 155         M3X
# 156         M4X
# 157         M5X
# 158         M6X
# 159         M7X
# 160         M8X
# 161         M9X
# 162         M1Y
# 163         M2Y
# 164         M3Y
# 165         M4Y
# 166         M5Y
# 167         M6Y
# 168         M7Y
# 169         M8Y
# 170         M9Y
# 171         M1Z
# 172         M2Z
# 173         M3Z
# 174         M4Z
# 175         M5Z
# 176         M6Z
# 177         M7Z
# 178         M8Z
# 179         M9Z
#
# [180 rows x 3 columns]

# %% [markdown]
# taking 'not assigned' records out of the data and printing the first five records

# %%
raw_data_selected = data[data['Borough'] != 'Not assigned']
raw_data_selected = raw_data_selected.groupby(['Borough', 'Postal Code'], as_index=False).agg(','.join)
raw_data_selected.head()
# Out:
#            Borough Postal Code                       Neighborhood
# 0  Central Toronto         M4N                      Lawrence Park
# 1  Central Toronto         M4P                   Davisville North
# 2  Central Toronto         M4R  North Toronto West, Lawrence Park
# 3  Central Toronto         M4S                         Davisville
# 4  Central Toronto         M4T        Moore Park, Summerhill East

# %%
raw_data_selected['Neighborhood'] = np.where(raw_data_selected['Neighborhood'] == 'Not assigned', raw_data_selected['Borough'], raw_data_selected['Neighborhood'])

# %%
raw_data_selected.shape
# Out:
# (103, 3)
